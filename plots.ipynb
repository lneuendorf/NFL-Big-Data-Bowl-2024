# %%
from plotter2 import NflPlayAnimator
import matplotlib.pyplot as plt

PlayAnimator = NflPlayAnimator()

# %%
anim = PlayAnimator.animate_play(gameId=2022091105	,playId=2742)

# %%
anim = PlayAnimator.animate_play(gameId=2022100903,playId=3266)

# %%
anim = PlayAnimator.animate_play(gameId=2022100202,playId=1293)

# %%
anim = PlayAnimator.animate_play(gameId=2022110300,playId=3506)

# %%
# Reciever ran ob and tackle was awarded to wrong defender
anim = PlayAnimator.animate_play(gameId=2022092510,playId=3356)

# %%
# ball assigned to wrong player
anim = PlayAnimator.animate_play(gameId=2022092500,playId=2218)

# %%
# ball coordinates WAY off
anim = PlayAnimator.animate_play(gameId=2022101603,playId=4087)

# %%
# Improper ball assignment
anim = PlayAnimator.animate_play(gameId=2022092500,playId=756)

# %%
# Intentional safety to end game
# anim = PlayAnimator.animate_play(gameId=2022110600,playId=3654)

# %%
anim = PlayAnimator.animate_play(gameId=2022101607,playId=489, tacklerId=46097)

# %%
anim = PlayAnimator.animate_play(gameId=2022100600 ,playId=4192, tacklerId=53581)

# %%
anim
# Out:
# <video width="1200" height="632" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df_games.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2022090800    2022     1  09/08/2022        20:20:00           LA
# 1  2022091100    2022     1  09/11/2022        13:00:00          ATL
# 2  2022091101    2022     1  09/11/2022        13:00:00          CAR
# 3  2022091102    2022     1  09/11/2022        13:00:00          CHI
# 4  2022091103    2022     1  09/11/2022        13:00:00          CIN
#
#   visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0             BUF              10                 31
# 1              NO              26                 27
# 2             CLE              24                 26
# 3              SF              19                 10
# 4             PIT              20                 23

# %% [markdown]
# # Todo
# * highlight ball carrier
# * highlight tackler
# * highlight ball carrier and tackler name

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

df_games = pd.read_csv('data/games.csv')
df_players = pd.read_csv('data/players.csv')
df_plays = pd.read_csv('data/plays.csv')
df_tackles = pd.read_csv('data/tackles.csv')

df_tracking = pd.DataFrame()
for week in range(1, 10):
    file_name = f'data/tracking_week_{week}.csv'
    df_tmp = pd.read_csv(file_name)
    df_tracking = pd.concat([df_tracking, df_tmp], ignore_index=True)

# %%
df_plays.insert(0, 'key', df_plays['gameId'].astype(str) + df_plays['playId'].astype(str))
df_plays['key'] = df_plays['key'].astype(int)
df_tackles.insert(0, 'key', df_tackles['gameId'].astype(str) + df_tackles['playId'].astype(str))
df_tackles['key'] = df_tackles['key'].astype(int)
df_tracking.insert(0, 'key', df_tracking['gameId'].astype(str) + df_tracking['playId'].astype(str))
df_tracking['key'] = df_tracking['key'].astype(int)

# %%
tackle_types_occurred = {'tackle&missed': [47871]}
frame = 3
gameId=2022100205
playId=3163
#df_tracking.query("gameId==@gameId & playId==@playId & frameId==@frame & nflId==47871 ") #in @tackle_types_occurred['tackle&missed']
df_tracking.query("nflId in @list")
# Out:
#                      key      gameId  playId    nflId  displayName  frameId  \
# 1328485    2022091200286  2022091200     286  47871.0  Cody Barton        1
# 1328486    2022091200286  2022091200     286  47871.0  Cody Barton        2
# 1328487    2022091200286  2022091200     286  47871.0  Cody Barton        3
# 1328488    2022091200286  2022091200     286  47871.0  Cody Barton        4
# 1328489    2022091200286  2022091200     286  47871.0  Cody Barton        5
# ...                  ...         ...     ...      ...          ...      ...
# 11911294  20221106083543  2022110608    3543  47871.0  Cody Barton        7
# 11911295  20221106083543  2022110608    3543  47871.0  Cody Barton        8
# 11911296  20221106083543  2022110608    3543  47871.0  Cody Barton        9
# 11911297  20221106083543  2022110608    3543  47871.0  Cody Barton       10
# 11911298  20221106083543  2022110608    3543  47871.0  Cody Barton       11
#
# ...

# %%
list = tackle_types_occurred['tackle&missed']

# %%
tackle_types_occurred['tackle&missed']
# Out:
# [47871]

# %%
que
