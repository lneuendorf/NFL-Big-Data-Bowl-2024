# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %matplotlib inline
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
! ls data/
# Out:
# games.csv           tracking_week_1.csv tracking_week_5.csv tracking_week_9.csv
# players.csv         tracking_week_2.csv tracking_week_6.csv
# plays.csv           tracking_week_3.csv tracking_week_7.csv
# tackles.csv         tracking_week_4.csv tracking_week_8.csv

# %%
df_games = pd.read_csv('data/games.csv')
df_players = pd.read_csv('data/players.csv')
df_plays = pd.read_csv('data/plays.csv')
df_tackles = pd.read_csv('data/tackles.csv')
df_w1 = pd.read_csv('data/tracking_week_1.csv')

# %%
df_games.head()
# Out:
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2022090800    2022     1  09/08/2022        20:20:00           LA
# 1  2022091100    2022     1  09/11/2022        13:00:00          ATL
# 2  2022091101    2022     1  09/11/2022        13:00:00          CAR
# 3  2022091102    2022     1  09/11/2022        13:00:00          CHI
# 4  2022091103    2022     1  09/11/2022        13:00:00          CIN
#
#   visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0             BUF              10                 31
# 1              NO              26                 27
# 2             CLE              24                 26
# 3              SF              19                 10
# 4             PIT              20                 23

# %%
df_players.head()
# Out:
#    nflId height  weight   birthDate     collegeName position     displayName
# 0  25511    6-4     225  1977-08-03        Michigan       QB       Tom Brady
# 1  29550    6-4     328  1982-01-22        Arkansas        T    Jason Peters
# 2  29851    6-2     225  1983-12-02      California       QB   Aaron Rodgers
# 3  30842    6-6     267  1984-05-19            UCLA       TE  Marcedes Lewis
# 4  33084    6-4     217  1985-05-17  Boston College       QB       Matt Ryan

# %%
df_plays.head()
# Out:
#        gameId  playId  ballCarrierId ballCarrierDisplayName  \
# 0  2022100908    3537          48723           Parker Hesse
# 1  2022091103    3126          52457         Chase Claypool
# 2  2022091111    1148          42547          Darren Waller
# 3  2022100212    2007          46461             Mike Boone
# 4  2022091900    1372          47857       Devin Singletary
#
#                                      playDescription  quarter  down  \
# 0  (7:52) (Shotgun) M.Mariota pass short middle t...        4     1
# 1  (7:38) (Shotgun) C.Claypool right end to PIT 3...        4     1
# 2  (8:57) D.Carr pass short middle to D.Waller to...        2     2
# 3  (13:12) M.Boone left tackle to DEN 44 for 7 ya...        3     2
# 4  (8:33) D.Singletary right guard to TEN 32 for ...        2     1
#
#    yardsToGo possessionTeam defensiveTeam yardlineSide  yardlineNumber  \
# 0         10            ATL            TB          ATL              41
# ...

# %%
df_tackles.head()
# Out:
#        gameId  playId  nflId  tackle  assist  forcedFumble  pff_missedTackle
# 0  2022090800     101  42816       1       0             0                 0
# 1  2022090800     393  46232       1       0             0                 0
# 2  2022090800     486  40166       1       0             0                 0
# 3  2022090800     646  47939       1       0             0                 0
# 4  2022090800     818  40107       1       0             0                 0

# %%
df_w1['nflId'] = pd.to_numeric(df_w1['nflId'], errors='coerce').astype('Int64')
df_w1.head()
# Out:
#        gameId  playId  nflId     displayName  frameId  \
# 0  2022090800      56  35472  Rodger Saffold        1
# 1  2022090800      56  35472  Rodger Saffold        2
# 2  2022090800      56  35472  Rodger Saffold        3
# 3  2022090800      56  35472  Rodger Saffold        4
# 4  2022090800      56  35472  Rodger Saffold        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#       s     a   dis       o     dir         event
# 0  1.62  1.15  0.16  231.74  147.90           NaN
# 1  1.67  0.61  0.17  230.98  148.53  pass_arrived
# ...

# %%
if "position" not in df_w1.columns:
    cols = ['nflId', 'position']
    df_play = df_w1.query("gameId==2022090800 & playId==56").merge(df_players[cols], how="left", on="nflId")
    col_to_move = df_play.pop('position')
    df_play.insert(4, 'position', col_to_move)

# %%
df_play.head()
# Out:
#        gameId  playId  nflId     displayName position  frameId  \
# 0  2022090800      56  35472  Rodger Saffold        G        1
# 1  2022090800      56  35472  Rodger Saffold        G        2
# 2  2022090800      56  35472  Rodger Saffold        G        3
# 3  2022090800      56  35472  Rodger Saffold        G        4
# 4  2022090800      56  35472  Rodger Saffold        G        5
#
#                          time  jerseyNumber club playDirection      x      y  \
# 0  2022-09-08 20:24:05.200000          76.0  BUF          left  88.37  27.27
# 1  2022-09-08 20:24:05.299999          76.0  BUF          left  88.47  27.13
# 2  2022-09-08 20:24:05.400000          76.0  BUF          left  88.56  27.01
# 3  2022-09-08 20:24:05.500000          76.0  BUF          left  88.64  26.90
# 4  2022-09-08 20:24:05.599999          76.0  BUF          left  88.72  26.80
#
#       s     a   dis       o     dir         event
# 0  1.62  1.15  0.16  231.74  147.90           NaN
# ...

# %%
list(df_players.position.unique())
# Out:
# ['QB',
#  'T',
#  'TE',
#  'WR',
#  'DE',
#  'NT',
#  'SS',
#  'FS',
#  'G',
#  'OLB',
#  'DT',
#  'CB',
#  'RB',
#  'C',
#  'ILB',
#  'MLB',
#  'FB',
#  'LS',
#  'DB']

# %%
offensive_positions = ['QB','T','TE','WR','NT','G','RB','C','FB']
defensive_positions = ['DE','SS','FS','OLB','DT','CB','ILB','MLB','DB']
special_teams_positions = ['K','P','LS','PR']

# %%
print(f"x:{df_w1.x.min()}, {df_w1.x.max()}")
print(f"y:{df_w1.y.min()}, {df_w1.y.max()}")
# Out:
# x:-1.27, 120.16
# y:-4.62, 58.25

# %%
frame_dict = df_play.query('frameId==20').to_dict()
# Calling the plotting function and displaying the figure
fig, ax = create_football_field(
    player_x=list(frame_dict['x'].values()), 
    player_y=list(frame_dict['y'].values()))
plt.show()

# %%
import plotter
import matplotlib.pyplot as plt

fig, ax = plotter.create_football_field()
plt.show()
